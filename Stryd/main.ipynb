# %%
import os
import datetime
import pandas as pd

# %%
#get all the files in the data directory
files = os.listdir("Data")

#filter out the files that are not .csv
files = [file for file in files if file[-4:] == ".csv"]
df1=pd.read_csv('Data\\'+files[0])
df1.tail()
# Out:
#        Timestamp  Power (w/kg)  Form Power (w/kg)  Air Power (w/kg)  \
# 4650  1692677144      3.479452           0.972603               0.0
# 4651  1692677145      3.465753           0.972603               0.0
# 4652  1692677146      3.438356           0.972603               0.0
# 4653  1692677147      3.424658           0.972603               0.0
# 4654  1692677148      3.397260           0.972603               0.0
#
#       Watch Speed (m/s)  Stryd Speed (m/s)  Watch Distance (meters)  \
# 4650            2.76563            2.76563                    12046
# 4651            2.76563            2.76563                    12048
# 4652            2.73828            2.73828                    12051
# 4653            2.71484            2.71484                    12053
# 4654            2.68750            2.68750                    12055
#
#       Stryd Distance (meters)  Stiffness  Stiffness/kg  Ground Time (ms)  \
# 4650                    12046     14.750      0.202055               226
# 4651                    12048     14.625      0.200342               228
# 4652                    12051     14.625      0.200342               228
# 4653                    12053     14.500      0.198630               230
# 4654                    12055     14.375      0.196918               232
#
#       Cadence (spm)  Vertical Oscillation (cm)  Watch Elevation (m)  \
# 4650            174                        7.4               734.15
# 4651            174                        7.4               734.21
# 4652            174                        7.4               734.35
# 4653            174                        7.4               734.42
# 4654            174                        7.3               734.49
#
#       Stryd Elevation (m)
# 4650               734.15
# 4651               734.21
# 4652               734.35
# 4653               734.42
# 4654               734.49

# %%
datetime.datetime.fromtimestamp(df1['Timestamp'][0])
# Out:
# datetime.datetime(2023, 8, 22, 5, 45, 51)

# %%
#from timestamp to datetime
def to_datetime(timestamp):
    return datetime.datetime.fromtimestamp(int(timestamp)/1000)

to_datetime(t)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[13], line 5
#       2 def to_datetime(timestamp):
#       3     return datetime.datetime.fromtimestamp(int(timestamp)/1000)
# ----> 5 to_datetime(t)
#
# Cell In[13], line 3, in to_datetime(timestamp)
#       2 def to_datetime(timestamp):
# ----> 3     return datetime.datetime.fromtimestamp(int(timestamp)/1000)
#
# OSError: [Errno 22] Invalid argument
