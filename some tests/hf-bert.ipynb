# %%
#import torch
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19040\114050328.py in <module>
#       1 #import torch
# ----> 2 import tensorflow as tf
#       3
#       4
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\tensorflow\__init__.py in <module>
#      49 from ._api.v2 import autograph
#      50 from ._api.v2 import bitwise
# ---> 51 from ._api.v2 import compat
#      52 from ._api.v2 import config
#      53 from ._api.v2 import data
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\tensorflow\_api\v2\compat\__init__.py in <module>
#      35 import sys as _sys
#      36
# ---> 37 from . import v1
#      38 from . import v2
#      39 from tensorflow.python.compat.compat import forward_compatibility_horizon
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\tensorflow\_api\v2\compat\v1\__init__.py in <module>
#      29 from . import autograph
#      30 from . import bitwise
# ---> 31 from . import compat
#      32 from . import config
#      33 from . import data
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\tensorflow\_api\v2\compat\v1\compat\__init__.py in <module>
#      36
#      37 from . import v1
# ---> 38 from . import v2
#      39 from tensorflow.python.compat.compat import forward_compatibility_horizon
#      40 from tensorflow.python.compat.compat import forward_compatible
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\tensorflow\_api\v2\compat\v1\compat\v2\__init__.py in <module>
#      26
#      27 from . import compat
# ---> 28 from tensorflow._api.v2.compat.v2 import __internal__
#      29 from tensorflow._api.v2.compat.v2 import __operators__
#      30 from tensorflow._api.v2.compat.v2 import audio
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\tensorflow\_api\v2\compat\v2\__init__.py in <module>
#      31 from . import autograph
#      32 from . import bitwise
# ---> 33 from . import compat
#      34 from . import config
#      35 from . import data
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\tensorflow\_api\v2\compat\v2\compat\__init__.py in <module>
#      36
#      37 from . import v1
# ---> 38 from . import v2
#      39 from tensorflow.python.compat.compat import forward_compatibility_horizon
#      40 from tensorflow.python.compat.compat import forward_compatible
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\tensorflow\_api\v2\compat\v2\compat\v2\__init__.py in <module>
#     330 _current_module = _sys.modules[__name__]
#     331 try:
# --> 332   from tensorboard.summary._tf import summary
#     333   _current_module.__path__ = (
#     334       [_module_util.get_parent_dir(summary)] + _current_module.__path__)
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\tensorboard\summary\__init__.py in <module>
#      20 # If the V1 summary API is accessible, load and re-export it here.
#      21 try:
# ---> 22     from tensorboard.summary import v1  # noqa: F401
#      23 except ImportError:
#      24     pass
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\tensorboard\summary\v1.py in <module>
#      21 from tensorboard.plugins.audio import summary as _audio_summary
#      22 from tensorboard.plugins.custom_scalar import summary as _custom_scalar_summary
# ---> 23 from tensorboard.plugins.histogram import summary as _histogram_summary
#      24 from tensorboard.plugins.image import summary as _image_summary
#      25 from tensorboard.plugins.pr_curve import summary as _pr_curve_summary
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\tensorboard\plugins\histogram\summary.py in <module>
#      33
#      34 from tensorboard.plugins.histogram import metadata
# ---> 35 from tensorboard.plugins.histogram import summary_v2
#      36
#      37
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\tensorboard\plugins\histogram\summary_v2.py in <module>
#      33 from tensorboard.plugins.histogram import metadata
#      34 from tensorboard.util import lazy_tensor_creator
# ---> 35 from tensorboard.util import tensor_util
#      36
#      37
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\tensorboard\util\tensor_util.py in <module>
#      18
#      19 from tensorboard.compat.proto import tensor_pb2
# ---> 20 from tensorboard.compat.tensorflow_stub import dtypes, compat, tensor_shape
#      21
#      22
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\__init__.py in <module>
#      20 from tensorboard.compat.proto.meta_graph_pb2 import *  # noqa
#      21 from tensorboard.compat.proto.summary_pb2 import *  # noqa
# ---> 22 from .dtypes import as_dtype  # noqa
#      23 from .dtypes import DType  # noqa
#      24 from .dtypes import string  # noqa
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py in <module>
#      17 import numpy as np
#      18
# ---> 19 from . import pywrap_tensorflow
#      20 from tensorboard.compat.proto import types_pb2
#      21
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\pywrap_tensorflow.py in <module>
#      20
#      21 from . import errors
# ---> 22 from .io import gfile
#      23
#      24
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\io\__init__.py in <module>
#      15
#      16
# ---> 17 from . import gfile  # noqa
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\io\gfile.py in <module>
#      31 try:
#      32     import botocore.exceptions
# ---> 33     import boto3
#      34
#      35     S3_ENABLED = True
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\boto3\__init__.py in <module>
#      15
#      16 from boto3.compat import _warn_deprecated_python
# ---> 17 from boto3.session import Session
#      18
#      19 __author__ = 'Amazon Web Services'
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\boto3\session.py in <module>
#      15 import os
#      16
# ---> 17 import botocore.session
#      18 from botocore.client import Config
#      19 from botocore.exceptions import DataNotFoundError, UnknownServiceError
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\botocore\session.py in <module>
#      24 import warnings
#      25
# ---> 26 import botocore.client
#      27 import botocore.configloader
#      28 import botocore.credentials
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\botocore\client.py in <module>
#      13 import logging
#      14
# ---> 15 from botocore import waiter, xform_name
#      16 from botocore.args import ClientArgsCreator
#      17 from botocore.auth import AUTH_TYPE_MAPS
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\botocore\waiter.py in <module>
#      16 import jmespath
#      17
# ---> 18 from botocore.docs.docstring import WaiterDocstring
#      19 from botocore.utils import get_service_module_name
#      20
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\botocore\docs\__init__.py in <module>
#      13 import os
#      14
# ---> 15 from botocore.docs.service import ServiceDocumenter
#      16
#      17
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\botocore\docs\service.py in <module>
#      12 # language governing permissions and limitations under the License.
#      13 from botocore.docs.bcdoc.restdoc import DocumentStructure
# ---> 14 from botocore.docs.client import ClientDocumenter, ClientExceptionsDocumenter
#      15 from botocore.docs.paginator import PaginatorDocumenter
#      16 from botocore.docs.waiter import WaiterDocumenter
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\botocore\docs\client.py in <module>
#      12 # language governing permissions and limitations under the License.
#      13 from botocore.compat import OrderedDict
# ---> 14 from botocore.docs.example import ResponseExampleDocumenter
#      15 from botocore.docs.method import (
#      16     document_custom_method,
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\botocore\docs\example.py in <module>
#      11 # ANY KIND, either express or implied. See the License for the specific
#      12 # language governing permissions and limitations under the License.
# ---> 13 from botocore.docs.shape import ShapeDocumenter
#      14 from botocore.docs.utils import py_default
#      15
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\botocore\docs\shape.py in <module>
#      17 # inherited from a Documenter class with the appropriate methods
#      18 # and attributes.
# ---> 19 from botocore.utils import is_json_value_header
#      20
#      21
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\botocore\utils.py in <module>
#      32 import botocore
#      33 import botocore.awsrequest
# ---> 34 import botocore.httpsession
#      35
#      36 # IP Regexes retained for backwards compatibility
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\botocore\httpsession.py in <module>
#      39 try:
#      40     # Always import the original SSLContext, even if it has been patched
# ---> 41     from urllib3.contrib.pyopenssl import orig_util_SSLContext as SSLContext
#      42 except ImportError:
#      43     from urllib3.util.ssl_ import SSLContext
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in <module>
#      48 from __future__ import absolute_import
#      49
# ---> 50 import OpenSSL.crypto
#      51 import OpenSSL.SSL
#      52 from cryptography import x509
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\OpenSSL\__init__.py in <module>
#       6 """
#       7
# ----> 8 from OpenSSL import crypto, SSL
#       9 from OpenSSL.version import (
#      10     __author__,
#
# c:\Users\matan.s\Anaconda3\lib\site-packages\OpenSSL\crypto.py in <module>
#    3266 # OpenSSL library (and is linked against the same one that cryptography is
#    3267 # using)).
# -> 3268 _lib.OpenSSL_add_all_algorithms()
#    3269
#    3270 # This is similar but exercised mainly by exception_from_error_queue.  It calls
#
# AttributeError: module 'lib' has no attribute 'OpenSSL_add_all_algorithms'

# %%
from transformers import BertTokenizer, TFBertModel
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = TFBertModel.from_pretrained("bert-base-uncased")
text = "Replace me by any text you'd like."
encoded_input = tokenizer(text, return_tensors='tf')
output = model(encoded_input)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27240\437569324.py in <module>
# ----> 1 from transformers import BertTokenizer, TFBertModel
#       2 tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
#       3 model = TFBertModel.from_pretrained("bert-base-uncased")
#       4 text = "Replace me by any text you'd like."
#       5 encoded_input = tokenizer(text, return_tensors='tf')
#
# ModuleNotFoundError: No module named 'transformers'
